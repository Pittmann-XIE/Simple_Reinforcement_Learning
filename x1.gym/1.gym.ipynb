# %%
#安装,如果出错,提示安装什么就安装什么
#pip install gym==0.26
#pip install ufal.pybox2d

# %%
import gym
from matplotlib import pyplot as plt
# %matplotlib inline

#创建一个游戏环境
env = gym.make('CartPole-v0', render_mode='rgb_array')

#初始化游戏
env.reset()

#显示游戏
plt.imshow(env.render())
plt.show()

#关闭游戏
env.close()
# Out:
# c:\Users\67077\.conda\envs\ptot2_3_0\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(

# %%
import gym
import matplotlib.pyplot as plt 
# %matplotlib inline

env = gym.make("CartPole-v0", render_mode= "rgb_array")

env.reset()
plt.imshow(env.render())
plt.show()
env.close()
# Out:
# c:\Users\67077\.conda\envs\ptot2_3_0\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(

# %%
import gym
import time

# Create the environment with human rendering
env = gym.make("CartPole-v0", render_mode="human")

# Reset the environment
env.reset()

# Render the environment (this will open a window)
for _ in range(50):
    env.render()
    time.sleep(0.1)

# Close the environment
env.close()

# %%
from IPython import display
import gym
import time

#创建月球着陆
env = gym.make('LunarLander-v2', render_mode='rgb_array')

#初始化游戏
state = env.reset()

#随机玩N个动作
for i in range(300):
    action = env.action_space.sample()
    state, reward, terminated, truncated, info = env.step(action)
    over = terminated or truncated

    if i % 5 == 0:  #跳帧
        #打印动画
        display.clear_output(wait=True)
        plt.imshow(env.render())
        plt.show()

    #游戏结束了就重置
    if over:
        state, info = env.reset()

#关闭游戏
env.close()

# %%
#游戏的动作空间
env.action_space
# Out:
# Discrete(4)

# %%
#游戏的状态空间
env.observation_space.high, env.observation_space.low
# Out:
# (array([1.5      , 1.5      , 5.       , 5.       , 3.1415927, 5.       ,
#         1.       , 1.       ], dtype=float32),
#  array([-1.5      , -1.5      , -5.       , -5.       , -3.1415927,
#         -5.       , -0.       , -0.       ], dtype=float32))

# %%
#反馈值空间
env.reward_range
# Out:
# (-inf, inf)

# %%
import gym
import pygame
from gym.utils.play import play

#定义按键映射
mapping = {(pygame.K_LEFT, ): 0, (pygame.K_RIGHT, ): 1}

#直接玩游戏游戏,这要求有图形界面
#play(gym.make('CartPole-v0'), keys_to_action=mapping)
# Out:
# /root/anaconda3/envs/pt39/lib/python3.9/site-packages/gym/utils/play.py:29: UserWarning: WARN: Matplotlib is not installed, run `pip install gym[other]`
#   logger.warn("Matplotlib is not installed, run `pip install gym[other]`")
